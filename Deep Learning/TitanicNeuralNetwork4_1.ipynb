# %% [markdown]
# <a href="https://colab.research.google.com/github/harisowndharyav01/AI/blob/main/Deep%20Learning/TitanicNeuralNetwork4_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data_test=pd.read_csv('https://raw.githubusercontent.com/ezioauditore-tech/AI/main/datasets/Titanic/test.csv')
data_train=pd.read_csv('https://raw.githubusercontent.com/ezioauditore-tech/AI/main/datasets/Titanic/train.csv')

# %%
y_train=data_train['Survived']

# %%
data_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data_train.drop(labels='Survived',axis=1,inplace=True)

# %%
data_train.shape
# Out:
# (891, 11)

# %%
train_test=data_train.append(data_test)
# Out:
# <ipython-input-7-8b130bddc849>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_test=data_train.append(data_test)

# %%
train_test.isnull().sum()
# Out:
# PassengerId       0
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %%
cols_to_drop=["Name","Age","SibSp","Ticket","Cabin","Parch","Embarked"]
train_test.drop(labels=cols_to_drop,axis=1,inplace=True)

# %%
train_test
# Out:
#      PassengerId  Pclass     Sex      Fare
# 0              1       3    male    7.2500
# 1              2       1  female   71.2833
# 2              3       3  female    7.9250
# 3              4       1  female   53.1000
# 4              5       3    male    8.0500
# ..           ...     ...     ...       ...
# 413         1305       3    male    8.0500
# 414         1306       1  female  108.9000
# 415         1307       3    male    7.2500
# 416         1308       3    male    8.0500
# 417         1309       3    male   22.3583
#
# [1309 rows x 4 columns]

# %%
train_test.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Sex            0
# Fare           1
# dtype: int64

# %%
train_test_dummies=pd.get_dummies(train_test,columns=["Sex"])

# %%
train_test_dummies.shape
# Out:
# (1309, 5)

# %%
train_test_dummies.fillna(value=0.0,inplace=True)

# %%
x_train=train_test_dummies.values[0:891]
x_test=train_test_dummies.values[891:]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
x_train_scale=scaler.fit_transform(x_train)
x_test_scale=scaler.transform(x_test)

# %%
from sklearn.model_selection import train_test_split
x_train_sub,x_test_sub,y_train_sub,y_test_sub=train_test_split(x_train_scale,y_train,random_state=0)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation='relu', input_shape=(x_train.shape[1],)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model
model.fit(x_train_sub, y_train_sub, epochs=50, batch_size=8, validation_split=0.2)

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(x_test_sub, y_test_sub)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
# Out:
# Epoch 1/50
# 67/67 [==============================] - 2s 7ms/step - loss: 0.5497 - accuracy: 0.7697 - val_loss: 0.4899 - val_accuracy: 0.7910
# Epoch 2/50
# 67/67 [==============================] - 0s 4ms/step - loss: 0.4723 - accuracy: 0.7903 - val_loss: 0.4611 - val_accuracy: 0.7910
# Epoch 3/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.4663 - accuracy: 0.7959 - val_loss: 0.4664 - val_accuracy: 0.7910
# Epoch 4/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.4548 - accuracy: 0.8071 - val_loss: 0.4707 - val_accuracy: 0.7687
# Epoch 5/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.4542 - accuracy: 0.8109 - val_loss: 0.4841 - val_accuracy: 0.7313
# Epoch 6/50
# 67/67 [==============================] - 0s 4ms/step - loss: 0.4532 - accuracy: 0.8127 - val_loss: 0.5020 - val_accuracy: 0.7239
# Epoch 7/50
# ...
